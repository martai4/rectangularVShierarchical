# %%
import json
import pandas as pd
import pyarrow as pa
import pyarrow.compute as pc

# %%
path = '../data-test/gists.json'

with open(path, encoding='utf-8') as f:
    dt = json.load(f)

# %%
dt
# Out:
# [{'url': 'https://api.github.com/gists/68b9a146fc3b08ec301f3cdd819ce2a2',
#   'forks_url': 'https://api.github.com/gists/68b9a146fc3b08ec301f3cdd819ce2a2/forks',
#   'commits_url': 'https://api.github.com/gists/68b9a146fc3b08ec301f3cdd819ce2a2/commits',
#   'id': '68b9a146fc3b08ec301f3cdd819ce2a2',
#   'node_id': 'G_kwDOAWatx9oAIDY4YjlhMTQ2ZmMzYjA4ZWMzMDFmM2NkZDgxOWNlMmEy',
#   'git_pull_url': 'https://gist.github.com/68b9a146fc3b08ec301f3cdd819ce2a2.git',
#   'git_push_url': 'https://gist.github.com/68b9a146fc3b08ec301f3cdd819ce2a2.git',
#   'html_url': 'https://gist.github.com/HugsLibRecordKeeper/68b9a146fc3b08ec301f3cdd819ce2a2',
#   'files': {'output_log.txt': {'filename': 'output_log.txt',
#     'type': 'text/plain',
#     'language': 'Text',
#     'raw_url': 'https://gist.githubusercontent.com/HugsLibRecordKeeper/68b9a146fc3b08ec301f3cdd819ce2a2/raw/38f045e858e8209e31639779515a9854df467f27/output_log.txt',
#     'size': 62780}},
#   'public': True,
# ...

# %%
df = pd.DataFrame(dt)

# %%
df
# Out:
#                                                  url  \
# 0  https://api.github.com/gists/68b9a146fc3b08ec3...
# 1  https://api.github.com/gists/d6b1f5d8307afbca6...
# 2  https://api.github.com/gists/5408bdaaa53fee815...
#
#                                            forks_url  \
# 0  https://api.github.com/gists/68b9a146fc3b08ec3...
# 1  https://api.github.com/gists/d6b1f5d8307afbca6...
# 2  https://api.github.com/gists/5408bdaaa53fee815...
#
#                                          commits_url  \
# 0  https://api.github.com/gists/68b9a146fc3b08ec3...
# 1  https://api.github.com/gists/d6b1f5d8307afbca6...
# 2  https://api.github.com/gists/5408bdaaa53fee815...
#
#                                  id  \
# 0  68b9a146fc3b08ec301f3cdd819ce2a2
# 1  d6b1f5d8307afbca6a346a0a978152a0
# 2  5408bdaaa53fee815c512b41a8dfef2d
#
#                                              node_id  \
# 0  G_kwDOAWatx9oAIDY4YjlhMTQ2ZmMzYjA4ZWMzMDFmM2Nk...
# 1  G_kwDOBz4FHNoAIGQ2YjFmNWQ4MzA3YWZiY2E2YTM0NmEw...
# ...

# %%
table = pa.Table.from_pandas(df)

# %%
table
# Out:
# pyarrow.Table
# url: string
# forks_url: string
# commits_url: string
# id: string
# node_id: string
# git_pull_url: string
# git_push_url: string
# html_url: string
# files: struct<gistfile1.txt: struct<filename: string, language: string, raw_url: string, size: int64, type: string>, output_log.txt: struct<filename: string, language: string, raw_url: string, size: int64, type: string>, swap.json: struct<filename: string, language: string, raw_url: string, size: int64, type: string>>
#   child 0, gistfile1.txt: struct<filename: string, language: string, raw_url: string, size: int64, type: string>
#       child 0, filename: string
#       child 1, language: string
#       child 2, raw_url: string
#       child 3, size: int64
#       child 4, type: string
#   child 1, output_log.txt: struct<filename: string, language: string, raw_url: string, size: int64, type: string>
#       child 0, filename: string
#       child 1, language: string
#       child 2, raw_url: string
# ...
